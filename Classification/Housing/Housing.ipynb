# %% [markdown]
# # Thesis:
# - Housing prices and when to buy

# %% [markdown]
# # Methods:
#
# - linear regression skills in order to predict what the price of a certain house should be.
# - logistic regression is a classification algorithm used for binary classification problems, where the output is either 0 or 1. It models the probability of the default class. TLDR: buy or don't buy.

# %% [markdown]
# # Libraries

# %%
# library for math
import numpy as np
# library for math
import pandas as pd
# library for graphs
import matplotlib.pyplot as plt
# library for stats and stats visuals
import seaborn as sns

# %% [markdown]
# # Dataset:
# - Boston House Prices

# %% [markdown]
# ## Data Importing

# %%
import os
import glob

path = 'C:\\Users\\OITRICKENNEN\\PycharmProjects\\Classifier\\Housing'
extension = 'csv'
os.chdir(path)
result = glob.glob('*.{}'.format(extension))
print(result)

# %%
df = pd.read_csv('National Housing Data.csv')

print(df.to_string())

# %% [markdown]
# ## Data Cleaning

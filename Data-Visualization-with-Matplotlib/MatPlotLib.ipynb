# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# use this to see plots in the notebook
# %matplotlib inline

# %%
var_1 = np.linspace(0, 5, 11) # goes from 0 to 5 and grabs 11 points
var_2 = var_1 ** 2 # var1 to the power of 2

# %%
var_1
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
var_2
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# # Matplotlib Basic Method

# %%
plt.plot(var_1,var_2)

# %%
# Graph with a color
plt.plot(var_1,var_2, 'r')

# %%
# Graph with a color
plt.plot(var_1,var_2, 'g')

# %%
#Obviously we need axis titles and more
plt.plot(var_1, var_2, 'r')
plt.xlabel('# of students')
plt.ylabel('Test Scores')
plt.title('Progress')
# Out:
# Text(0.5, 1.0, 'Progress')

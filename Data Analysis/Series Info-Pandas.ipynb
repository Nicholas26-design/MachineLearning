# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']
my_data = [10,20,30]
arr = np.array(my_data)
d = {'a':10, 'b':20, 'c':30}

# %% [markdown]
# Series

# %%
pd.Series(my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# Using an index (Grabbing info from series)

# %%
ser1 = pd.Series([1,2,3,4], ['USA', 'Germany', 'USSR', 'Japan'])
ser2 = pd.Series([1,2,5,4], ['USA', 'Germany', 'Italy', 'Japan'])

# %%
# Using an index (Grabbing info from series)

ser1['USA']
ser1[1]

# We've done this before in prior.
# Out:
# 2
